# %%
# First of all we import the all imp Libraries from python

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Now we copy the path of the Dataset from the sourcecode

# %%
df=pd.read_csv("/content/fifa worldcup 2022.csv")

# %%
df
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
df.shape
# It shows the overall rows and columns of the dataset
# Out:
# (23921, 25)

# %%
# Now we remove all unwanted Outliers from the dataset with using drop() function

# %%
df.drop(["home_team_goalkeeper_score","away_team_goalkeeper_score","away_team_goalkeeper_score","home_team_mean_defense_score"],axis=1,inplace=True)

# %%
df
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
df.drop(["home_team_mean_offense_score","home_team_mean_midfield_score","away_team_mean_defense_score"],axis=1,inplace=True)

# %%
df
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
df.drop(["away_team_mean_offense_score","away_team_mean_midfield_score","date"],axis=1,inplace=True)

# %%
df
# Out:
#             home_team     away_team home_team_continent away_team_continent  \
# 0             Bolivia       Uruguay       South America       South America
# 1              Brazil        Mexico       South America       North America
# 2             Ecuador     Venezuela       South America       South America
# 3              Guinea  Sierra Leone              Africa              Africa
# 4            Paraguay     Argentina       South America       South America
# ...               ...           ...                 ...                 ...
# 23916         Moldova       Andorra              Europe              Europe
# 23917   Liechtenstein        Latvia              Europe              Europe
# 23918           Chile         Ghana       South America              Africa
# 23919           Japan       Tunisia                Asia              Africa
# 23920  Korea Republic         Egypt                Asia              Africa
#
# ...

# %%
# Now we use LabelEncoder to convert categorical data into numerical data

# %%
from sklearn.preprocessing import LabelEncoder

# %%
home_team	=LabelEncoder()
away_team=LabelEncoder()
home_team_continent=LabelEncoder()
away_team_continent	=LabelEncoder()

# %%
df["home_team"]=home_team.fit_transform(df["home_team"])
df["away_team"]=away_team.fit_transform(df["away_team"])
df["home_team_continent"]=home_team_continent.fit_transform(df["home_team_continent"])
df["away_team_continent"]=away_team_continent.fit_transform(df["away_team_continent"])

# %%
df
# Out:
#        home_team  away_team  home_team_continent  away_team_continent  \
# 0             24        202                    5                    5
# 1             27        124                    5                    3
# 2             59        205                    5                    5
# 3             82        166                    0                    0
# 4            148          8                    5                    5
# ...          ...        ...                  ...                  ...
# 23916        125          4                    2                    2
# 23917        112        107                    2                    2
# 23918         40         76                    5                    0
# 23919         97        193                    1                    0
# 23920        102         60                    1                    0
#
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
tournament=LabelEncoder()
city=LabelEncoder()
country	=LabelEncoder()
neutral_location=LabelEncoder()
shoot_out=LabelEncoder()
home_team_result=LabelEncoder()

# %%
df["tournament"]=tournament.fit_transform(df["tournament"])
df["city"]=city.fit_transform(df["city"])
df["country"]=country.fit_transform(df["country"])
df["neutral_location"]=neutral_location.fit_transform(df["neutral_location"])
df["shoot_out"]=shoot_out.fit_transform(df["shoot_out"])
df["home_team_result"]=home_team_result.fit_transform(df["home_team_result"])

# %%
df
# Out:
#        home_team  away_team  home_team_continent  away_team_continent  \
# 0             24        202                    5                    5
# 1             27        124                    5                    3
# 2             59        205                    5                    5
# 3             82        166                    0                    0
# 4            148          8                    5                    5
# ...          ...        ...                  ...                  ...
# 23916        125          4                    2                    2
# 23917        112        107                    2                    2
# 23918         40         76                    5                    0
# 23919         97        193                    1                    0
# 23920        102         60                    1                    0
#
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# ...

# %%
# Now we seperate out features(x) and Label(y) from the dataset with using iloc() function

# %%
x=df.iloc[:,0:15]

# %%
x
# Out:
#        home_team  away_team  home_team_continent  away_team_continent  \
# 0             24        202                    5                    5
# 1             27        124                    5                    3
# 2             59        205                    5                    5
# 3             82        166                    0                    0
# 4            148          8                    5                    5
# ...          ...        ...                  ...                  ...
# 23916        125          4                    2                    2
# 23917        112        107                    2                    2
# 23918         40         76                    5                    0
# 23919         97        193                    1                    0
# 23920        102         60                    1                    0
#
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# ...

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0        2
# 1        0
# 2        2
# 3        2
# 4        1
#         ..
# 23916    2
# 23917    1
# 23918    1
# 23919    1
# 23920    2
# Name: home_team_result, Length: 23921, dtype: int64

# %%
# Now we use Sciket_learn to train and test the model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 19136

# %%
len(x_test)
# Out:
# 4785

# %%
# Now we use StandardScaler process to range the data between 0 and 1

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.54449873,  0.57222962,  0.23148236, ...,  1.40408874,
#         -0.57614343, -0.11713411],
#        [-0.19237986, -0.36007232,  0.93965926, ..., -0.28954534,
#         -0.57614343, -0.11713411],
#        [ 0.94327153,  0.77200861,  0.23148236, ...,  0.85522584,
#         -0.57614343, -0.11713411],
#        ...,
#        [ 1.04347606, -0.45996182,  1.64783615, ...,  0.36909014,
#          1.7356789 , -0.11713411],
#        [-1.11092142,  0.88854635, -0.47669453, ..., -1.19908956,
#         -0.57614343, -0.11713411],
#        [ 0.79296473, -1.37561551,  0.23148236, ...,  0.68272608,
#         -0.57614343, -0.11713411]])

# %%
x_test=sc.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 0.69986913,  1.57467928,  2.33052031, ...,  0.59157525,
#         -0.58016565, -0.12446831],
#        [-0.4922893 ,  1.1075048 ,  0.21621714, ..., -0.59325572,
#         -0.58016565, -0.12446831],
#        [-0.32437966,  0.90728716,  0.21621714, ..., -0.41948051,
#         -0.58016565, -0.12446831],
#        ...,
#        [-0.54266219, -0.21059464,  0.21621714, ..., -0.64064896,
#         -0.58016565, -0.12446831],
#        [ 1.08606129, -0.87798676, -1.19331831, ..., -0.71963769,
#          1.72364566, -0.12446831],
#        [-0.97922725, -0.32738826,  0.21621714, ..., -1.08298585,
#         -0.58016565, -0.12446831]])

# %%
# Now we are using DecisiontreeClassifier algorithem to predict accuracy score

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.9905956112852664

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 0, 2])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
Cf=confusion_matrix(y_test,y_pred)

# %%
Cf
# Out:
# array([[1100,    0,    1],
#        [   0, 1332,   25],
#        [   0,   19, 2308]])

# %%
# Now we are Plotting the Chart

# %%
sns.countplot(x="home_team_result",data=df)
